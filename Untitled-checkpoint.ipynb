# %%
# !pip install --upgrade pandas
# !pip install openpyxl
import pandas as pd
import matplotlib.pyplot as plt
# !pip install xlrd
import xlrd as x

# %%
project11 = pd.read_excel(r'C:\Users\afats\Downloads\assign 1\file1.1.xlsx')

# %%
project11
# Out:
#    Column1                                            Column2 Column3 Column4  \
# 0    sr no                                      All countries   TOTAL   Women
# 1        1                                             Sweden    4731    2236
# 2        2                                              India    3681    1848
# 3        3                                             Poland    2234     773
# 4        4                                        Afghanistan    1513     869
# 5        5                               Syrian Arab Republic    1505     877
# 6        6                                            Germany    1429     689
# 7        7                          Iran, Islamic Republic of    1295     692
# 8        8                                           Pakistan    1249     590
# 9        9                                            Türkiye     969     432
# 10      10                                            Romania     955     320
# ...

# %%
project12 = pd.read_excel(r'C:\Users\afats\Downloads\assign 1\file1.2.xlsx')

# %%
project12
# Out:
#    Column1                                            Column2 Column3 Column4  \
# 0    SR NO                                      ALL COUNTRIES   TOTAL   WOMEN
# 1        1                                             Sweden    4481    2156
# 2        2                                              India    3561    1686
# 3        3                                             Poland    2005     629
# 4        4                                        Afghanistan    1441     725
# 5        5                               Syrian Arab Republic    1675     904
# 6        6                                            Germany    1520     755
# 7        7                          Iran, Islamic Republic of    1254     676
# 8        8                                           Pakistan    1235     579
# 9        9                                            Türkiye    1201     528
# 10      10                                            Romania    1034     374
# ...

# %%
project21 = pd.read_excel(r'C:\Users\afats\Downloads\assign 1\file2.1.xlsx')

# %%
project21
# Out:
#    Column1                                            Column2      l Column3  \
# 0    SR NO                                      ALL COUNTRIES  TOTAL   WOMEN
# 1        1                                             Sweden   9666    4618
# 2        2                               Syrian Arab Republic   1317     649
# 3        3                                              India   1046     433
# 4        4                                               Iraq    990     462
# 5        5                                             Poland    710     287
# 6        6                                            Finland    690     387
# 7        7                                            Somalia    685     413
# 8        8                                            Germany    684     341
# 9        9                                            Denmark    658     315
# 10      10                                              China    417     202
# ...

# %%
project22 = pd.read_excel(r'C:\Users\afats\Downloads\assign 1\file2.2.xlsx')

# %%
project22
# Out:
#    Column1                                            Column2 Column3 Column4  \
# 0    SR NO                                      ALL COUNTRIES   TOTAL   WOMEN
# 1        1                                             Sweden    7668    3683
# 2        2                               Syrian Arab Republic     655     332
# 3        3                                              India     732     299
# 4        4                                               Iraq     708     288
# 5        5                                             Poland     637     264
# 6        6                                            Finland     712     401
# 7        7                                            Somalia     455     256
# 8        8                                            Germany     622     312
# 9        9                                            Denmark     674     313
# 10      10                                              China     354     181
# ...

# %%
project31 = pd.read_excel(r'C:\Users\afats\Downloads\assign 1\file3.1.xlsx')

# %%
project31
# Out:
#    Column2                                            Column3 Column4 Column5  \
# 0    SR NO                                      All countries   TOTAL   WOMEN
# 1        1                                             Sweden    4481    2156
# 2        2                                              India    3561    1686
# 3        3                                             Poland    2005     629
# 4        4                               Syrian Arab Republic    1675     904
# 5        5                                            Germany    1520     755
# 6        6                                        Afghanistan    1441     725
# 7        7                          Iran, Islamic Republic of    1254     676
# 8        8                                           Pakistan    1235     579
# 9        9                                             Turkey    1201     528
# 10      10                                            Romania    1034     374
# ...

# %%
project32 = pd.read_excel(r'C:\Users\afats\Downloads\assign 1\file3.2.xlsx')

# %%
project32
# Out:
#    Column1                                            Column2 Column4 Column5  \
# 0    SR NO                                      ALL COUNTRIES   TOTAL   WOMEN
# 1        1                                             Sweden    4499    2160
# 2        2                                              India    1904     931
# 3        3                                             Poland    1094     383
# 4        4                               Syrian Arab Republic    1197     636
# 5        5                                            Germany     924     459
# 6        6                                        Afghanistan     637     300
# 7        7                          Iran, Islamic Republic of     948     468
# 8        8                                           Pakistan     932     452
# 9        9                                             Turkey     820     364
# 10      10                                            Romania     535     187
# ...

# %%
project41 = pd.read_excel(r'C:\Users\afats\Downloads\assign 1\file4.1.xlsx')

# %%
project41
# Out:
#    Column1                                            Column2 Column3 Column4  \
# 0    sr no                                      All countries   TOTAL   Women
# 1        1                                             Sweden    7668    3683
# 2        2                                              India     732     299
# 3        3                                            Finland     712     401
# 4        4                                               Iraq     708     288
# 5        5                                            Denmark     674     313
# 6        6                               Syrian Arab Republic     655     332
# 7        7                                             Poland     637     264
# 8        8                                            Germany     622     312
# 9        9                                            Somalia     455     256
# 10      10  United Kingdom of Great Britain and Northern I...     449     186
# ...

# %%
project42 = pd.read_excel(r'C:\Users\afats\Downloads\assign 1\file4.2.xlsx')

# %%
project42
# Out:
#    Column1                                            Column2 Column3 Column4  \
# 0    SR NO                                      All countries   Total   Women
# 1        1                                             Sweden    7739    3848
# 2        2                                              India     912     370
# 3        3                                            Finland     912     508
# 4        4                                               Iraq     836     385
# 5        5                                            Denmark     676     332
# 6        6                               Syrian Arab Republic     465     210
# 7        7                                             Poland     875     347
# 8        8                                            Germany     623     322
# 9        9                                            Somalia     477     281
# 10      10  United Kingdom of Great Britain and Northern I...     400     175
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
countries = ['Sweden', 'India', 'Poland', 'Afghanistan', 'Syrian Arab Republic', 'Germany', 
             'Iran, Islamic Republic of', 'Pakistan', 'Türkiye', 'Romania', 'Iraq', 
             'Russian Federation', 'China', 'Denmark', 'United States', 'Finland', 'Italy', 
             'Netherlands', 'United Kingdom', 'Norway' ,'other countries']

total_population = [4731, 3681, 2234, 1513, 1505, 1429, 1295, 1249, 969, 955, 893, 687, 687, 
                    667, 624, 594, 592, 585, 548, 546,15764]

women_population = [2236, 1848, 773, 869, 877, 689, 692, 590, 432, 320, 416, 393, 355, 295, 
                    319, 319, 242, 251, 223, 243,7576]

men_population = [2495, 1833, 1461, 644, 628, 740, 603, 659, 537, 635, 477, 294, 332, 372, 
                  305, 275, 350, 334, 325, 303,8188]

percentage_change = [5.6, 3.4, 11.4, 5, -10.1, -6.0, 3.3, 1.1, -19.3, -7.6, 5.9, 22.2, 35.8, 
                     13.6, -7.4, 1.7, 4.2, 11.6, -11.8, 12.6,-6.1]

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar graphs for women and men
bar_width = 0.35
index = np.arange(len(countries))

bar1 = ax1.bar(index - bar_width/2, women_population, bar_width, label='Women', color='skyblue')
bar2 = ax1.bar(index + bar_width/2, men_population, bar_width, label='Men', color='lightcoral')

# Create a secondary y-axis (ax2) for the line graph
ax2 = ax1.twinx()

# Line graph for percentage change
line = ax2.plot(index, percentage_change, marker='o', color='green', label='Percentage Change')

# Set labels and title
ax1.set_xlabel('Countries')
ax1.set_ylabel('Population')
ax2.set_ylabel('Percentage Change (%)')

# Rotate x-axis labels for better readability
ax1.set_xticks(index)
ax1.set_xticklabels(countries, rotation=45, ha='right')

# Add legends, filtering out artists with labels starting with an underscore
bars = bar1 + bar2
labels = [bar.get_label() for bar in bars]
ax1.legend([bar for bar in bars if not bar.get_label().startswith('_')], 
           [label for label in labels if not label.startswith('_')], loc='upper left')

# Add a legend inside the graph for Men and Women colors
legend_labels = {'Men': 'lightcoral', 'Women': 'skyblue'}
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=label)
                  for label, color in legend_labels.items()]
ax1.legend(handles=legend_handles, loc='upper right', bbox_to_anchor=(1, 1))

# Show the plot
plt.title('Immigration to Sweden first half of 2022')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
data = {
    'Countries': ['Sweden', 'India', 'Poland', 'Afghanistan', 'Syrian Arab Republic', 'Germany', 
                  'Iran, Islamic Republic of', 'Pakistan', 'Türkiye', 'Romania', 'Iraq', 
                  'Russian Federation', 'China', 'Denmark', 'United States', 'Finland', 'Italy', 
                  'Netherlands', 'United Kingdom', 'Norway','other countries'],
    'Total': [4481, 3561, 2005, 1441, 1675, 1520, 1254, 1235, 1201, 1034, 843, 506, 562, 587, 
              674, 584, 568, 524, 621, 485,16780],
    'Women': [2156, 1686, 629, 725, 904, 755, 676, 579, 528, 374, 386, 308, 309, 255, 330, 
              322, 255, 256, 245, 241,7952],
    'Men': [2325, 1875, 1376, 716, 771, 765, 578, 656, 673, 660, 457, 198, 253, 332, 344, 
            262, 313, 268, 376, 244,8828]
}

df = pd.DataFrame(data)

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar graphs for women and men
bar_width = 0.35
index = np.arange(len(df['Countries']))

bar1 = ax1.bar(index - bar_width/2, df['Women'], bar_width, label='Women', color='skyblue')
bar2 = ax1.bar(index + bar_width/2, df['Men'], bar_width, label='Men', color='lightcoral')

# Create a secondary y-axis (ax2) for the line graph
ax2 = ax1.twinx()

# Line graph for total counts
line = ax2.plot(index, df['Total'], marker='o', color='green', label='Total')

# Set labels and title
ax1.set_xlabel('Countries')
ax1.set_ylabel('Population')
ax2.set_ylabel('Total Population')

# Rotate x-axis labels for better readability
ax1.set_xticks(index)
ax1.set_xticklabels(df['Countries'], rotation=45, ha='right')

# Add legends inside the graph for Men and Women
legend_labels = {'Men': 'lightcoral', 'Women': 'skyblue'}
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=label)
                  for label, color in legend_labels.items()]
ax1.legend(handles=legend_handles, loc='upper right', bbox_to_anchor=(1, 1))

# Show the plot
plt.title('Immigration to Sweden first half of 2023')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
data = {
    'Countries': ['Sweden', 'Syrian Arab Republic', 'India', 'Iraq', 'Poland', 'Finland', 
                  'Somalia', 'Germany', 'Denmark', 'China', 'Norway', 
                  'United Kingdom of Great Britain and Northern Ireland', 'United States', 
                  'Romania', 'Iran, Islamic Republic of', 'Türkiye', 'France', 'Italy', 
                  'Pakistan', 'Spain','other countries'],
    'Total': [9666, 1317, 1046, 990, 710, 690, 685, 684, 658, 417, 411, 402, 370, 327, 326, 
              316, 309, 300, 283, 269,26425],
    'Women': [4618, 649, 433, 462, 287, 387, 413, 341, 315, 202, 211, 152, 188, 148, 148, 
              116, 132, 110, 118, 117,12460],
    'Men': [5048, 668, 613, 528, 423, 303, 272, 343, 343, 215, 200, 250, 182, 179, 178, 
            200, 177, 190, 165, 152,13965]
}

df = pd.DataFrame(data)

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar graphs for women and men
bar_width = 0.35
index = np.arange(len(df['Countries']))

bar1 = ax1.bar(index - bar_width/2, df['Women'], bar_width, label='Women', color='skyblue')
bar2 = ax1.bar(index + bar_width/2, df['Men'], bar_width, label='Men', color='lightcoral')

# Create a secondary y-axis (ax2) for the line graph
ax2 = ax1.twinx()

# Line graph for total counts
line = ax2.plot(index, df['Total'], marker='o', color='green', label='Total')

# Set labels and title
ax1.set_xlabel('Countries')
ax1.set_ylabel('Population')
ax2.set_ylabel('Total Population')

# Rotate x-axis labels for better readability
ax1.set_xticks(index)
ax1.set_xticklabels(df['Countries'], rotation=45, ha='right')

# Add legends inside the graph for Men and Women
legend_labels = {'Men': 'lightcoral', 'Women': 'skyblue'}
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=label)
                  for label, color in legend_labels.items()]
ax1.legend(handles=legend_handles, loc='upper right', bbox_to_anchor=(1, 1))



# Show the plot
plt.title('Emigration of Sweden first half of 2023')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
countries = ['Sweden', 'India', 'Poland', 'Afghanistan', 'Syrian Arab Republic', 'Germany', 'Iran, Islamic Republic of',
             'Pakistan', 'Türkiye', 'Romania', 'Iraq', 'Russian Federation', 'China', 'Denmark', 'United States',
             'Finland', 'Italy', 'Netherlands', 'United Kingdom', 'Norway','other countries']

women_counts = [2236, 1848, 773, 869, 877, 689, 692, 590, 432, 320, 416, 393, 355, 295, 319, 319, 242, 251, 223, 243,2478]
men_counts = [2495, 1833, 1461, 644, 628, 740, 603, 659, 537, 635, 477, 294, 332, 372, 305, 275, 350, 334, 325, 303,2725]
total_counts = np.array(women_counts) + np.array(men_counts)

percentages = [5.6, 3.4, 11.4, 5.0, -10.1, -6.0, 3.3, 1.1, -19.3, -7.6, 5.9, 22.2, 35.8, 13.6, -7.4, 1.7, 4.2, 11.6, -11.8, 12.6,20.1]

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar graphs for women and men
bar_width = 0.35
index = np.arange(len(countries))

bar1 = ax1.bar(index - bar_width/2, women_counts, bar_width, label='Women', color='skyblue')
bar2 = ax1.bar(index + bar_width/2, men_counts, bar_width, label='Men', color='lightcoral')

# Create a secondary y-axis (ax2) for the line graph
ax2 = ax1.twinx()

# Line graph for percentages
line = ax2.plot(index, percentages, marker='o', color='green')

# Set labels and title
ax1.set_xlabel('Countries')
ax1.set_ylabel('Counts', color='black')  # Common y-axis label for both bar graphs

# Rotate x-axis labels for better readability
ax1.set_xticks(index)
ax1.set_xticklabels(countries, rotation=45, ha='right')

# Add legends for Men, Women, and Percentage Change
ax1.legend(loc='upper right')


# Show the plot
plt.title('Emigration from Sweden first half of 2022')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
data = {
    'Countries': ['Sweden', 'India', 'Poland', 'Syrian Arab Republic', 'Germany', 'Afghanistan',
                   'Iran, Islamic Republic of', 'Pakistan', 'Turkey', 'Romania', 'Iraq', 'Brazil',
                   'United States', 'United Kingdom', 'Ukraine', 'Denmark', 'Finland', 'Italy',
                   'China', 'Lithuania', 'Other countries'],
    'Women': [2156, 1686, 629, 904, 755, 725, 676, 579, 528, 374, 386, 381, 330, 245, 339, 255, 322, 255, 309, 173, 7864],
    'Men': [2325, 1875, 1376, 771, 765, 716, 578, 656, 673, 660, 457, 393, 344, 376, 253, 332, 262, 313, 253, 376, 8516],
    'Total': [4481, 3561, 2005, 1675, 1520, 1441, 1254, 1235, 1201, 1034, 843, 774, 674, 621, 592, 587, 584, 568, 562, 549, 16380],
}

df = pd.DataFrame(data)

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Grouped bar graph for men and women
bar_width = 0.35
index = np.arange(len(df))

bar1 = ax1.bar(index - bar_width/2, df['Women'], bar_width, label='Women', color='skyblue')
bar2 = ax1.bar(index + bar_width/2, df['Men'], bar_width, label='Men', color='lightcoral')

# Create a secondary y-axis (ax2) for the line graph
ax2 = ax1.twinx()

# Line graph for total population
line = ax2.plot(index, df['Total'], marker='o', color='green', label='Total Population')

# Set labels and title
ax1.set_xlabel('Countries')
ax1.set_ylabel('Population')
ax2.set_ylabel('Total Population')

# Rotate x-axis labels for better readability
ax1.set_xticks(index)
ax1.set_xticklabels(df['Countries'], rotation=45, ha='right')

# Add legends for Men, Women, and Total Population
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.title('Immigration to Sweden first half of 2022')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Your data
data = {
    'Countries': ['Sweden', 'India', 'Poland', 'Syrian Arab Republic', 'Germany', 'Afghanistan',
                   'Iran, Islamic Republic of', 'Pakistan', 'Turkey', 'Romania', 'Iraq', 'Brazil',
                   'United States', 'United Kingdom of Great Britain and Northern Ireland',
                   'Ukraine', 'Denmark', 'Finland', 'Italy', 'China', 'Lithuania', 'Other countries', 'Total'],
    'Women': [2160, 931, 383, 636, 459, 300, 468, 452, 364, 187, 437, 229, 310, 175, 262, 253, 312, 145, 283, 105, 7293, 16144],
    'Men': [2339, 973, 711, 561, 465, 337, 480, 480, 456, 348, 444, 204, 333, 271, 206, 286, 238, 202, 230, 187, 7005, 16756],
    'Total': [4499, 1904, 1094, 1197, 924, 637, 948, 932, 820, 535, 881, 433, 643, 446, 468, 539, 550, 347, 513, 292, 14298, 32900],
    '%': [-0.4, 87, 83.3, 39.9, 64.5, 126.2, 32.3, 32.5, 46.5, 93.3, -4.3, 78.8, 4.8, 39.2, 26.5, 8.9, 6.2, 63.7, 9.6, 88, 14.6, 28.1],
}

df = pd.DataFrame(data)

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Grouped bar graph for men and women
bar_width = 0.35
index = np.arange(len(df) - 1)  # Exclude the last row ("Total")

bar1 = ax1.bar(index - bar_width/2, df['Women'][:-1], bar_width, label='Women', color='skyblue')
bar2 = ax1.bar(index + bar_width/2, df['Men'][:-1], bar_width, label='Men', color='lightcoral')

# Create a secondary y-axis (ax2) for the line graph
ax2 = ax1.twinx()

# Line graph for total population
line = ax2.plot(index, df['Total'][:-1], marker='o', color='green', label='Total Population')

# Set labels and title
ax1.set_xlabel('Countries')
ax1.set_ylabel('Population')
ax2.set_ylabel('Total Population')

# Rotate x-axis labels for better readability
ax1.set_xticks(index)
ax1.set_xticklabels(df['Countries'][:-1], rotation=45, ha='right')

# Add legends for Men, Women, and Total Population
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.title('Immigration to Sweden first half of 2023')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Your data
data = {
    'Countries': ['Sweden', 'India', 'Finland', 'Iraq', 'Denmark', 'Syrian Arab Republic', 'Poland', 'Germany',
                   'Somalia', 'United Kingdom of Great Britain and Northern Ireland', 'Norway', 'United States',
                   'China', 'Turkey', 'Spain', 'France', 'Italy', 'Pakistan', 'Romania', 'Brazil', 'Other countries', 'TOTAL'],
    'Women': [3683, 299, 401, 288, 313, 332, 264, 312, 256, 186, 229, 189, 181, 97, 121, 119, 107, 111, 102, 101, 2461, 10152],
    'Men': [3985, 433, 311, 420, 361, 323, 373, 310, 199, 263, 193, 207, 173, 172, 145, 138, 137, 129, 133, 106, 2737, 11248],
    'Total': [7668, 732, 712, 708, 674, 655, 637, 622, 455, 449, 422, 396, 354, 269, 266, 257, 244, 240, 235, 207, 5198, 21400],
}

df = pd.DataFrame(data)

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Grouped bar graph for men and women
bar_width = 0.35
index = np.arange(len(df) - 1)  # Exclude the last row ("TOTAL")

bar1 = ax1.bar(index - bar_width/2, df['Women'][:-1], bar_width, label='Women', color='skyblue')
bar2 = ax1.bar(index + bar_width/2, df['Men'][:-1], bar_width, label='Men', color='lightcoral')

# Create a secondary y-axis (ax2) for the line graph
ax2 = ax1.twinx()

# Line graph for total population
line = ax2.plot(index, df['Total'][:-1], marker='o', color='green', label='Total Population')

# Set labels and title
ax1.set_xlabel('Countries')
ax1.set_ylabel('Population')
ax2.set_ylabel('Total Population')

# Rotate x-axis labels for better readability
ax1.set_xticks(index)
ax1.set_xticklabels(df['Countries'][:-1], rotation=45, ha='right')

# Add legends for Men, Women, and Total Population
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.title('Emigration from Sweden first six months 2022')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Your data
data = {
    'Countries': ['Sweden', 'India', 'Finland', 'Iraq', 'Denmark', 'Syrian Arab Republic', 'Poland', 'Germany',
                   'Somalia', 'United Kingdom of Great Britain and Northern Ireland', 'Norway', 'United States',
                   'China', 'Turkey', 'Spain', 'France', 'Italy', 'Pakistan', 'Romania', 'Brazil', 'Other countries', 'TOTAL'],
    'Women': [3848, 370, 508, 385, 332, 210, 347, 322, 281, 175, 268, 216, 220, 102, 128, 107, 100, 109, 146, 78, 2803, 11055],
    'Men': [3891, 542, 404, 451, 344, 255, 528, 301, 196, 225, 228, 245, 218, 199, 150, 137, 118, 147, 184, 74, 3190, 12027],
    'Total': [7739, 912, 912, 836, 676, 465, 875, 623, 477, 400, 496, 461, 438, 301, 278, 244, 218, 256, 330, 152, 5993, 23082],
    '%': [-0.9, -19.7, -21.9, -15.3, -0.3, 40.9, -27.2, -0.2, -4.6, 12.3, -14.9, -14.1, -19.2, -10.6, -4.3, 5.3, 11.9, -6.3, -28.8, 36.2, -13.3, -7.3],
}

df = pd.DataFrame(data)

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Grouped bar graph for men and women
bar_width = 0.35
index = np.arange(len(df) - 1)  # Exclude the last row ("TOTAL")

bar1 = ax1.bar(index - bar_width/2, df['Women'][:-1], bar_width, label='Women', color='skyblue')
bar2 = ax1.bar(index + bar_width/2, df['Men'][:-1], bar_width, label='Men', color='lightcoral')

# Create a secondary y-axis (ax2) for the line graph
ax2 = ax1.twinx()

# Line graph for total population
line = ax2.plot(index, df['Total'][:-1], marker='o', color='green', label='Total Population')

# Set labels and title
ax1.set_xlabel('Countries')
ax1.set_ylabel('Population')
ax2.set_ylabel('Total Population')

# Rotate x-axis labels for better readability
ax1.set_xticks(index)
ax1.set_xticklabels(df['Countries'][:-1], rotation=45, ha='right')

# Add legends for Men, Women, and Total Population
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.title('Emigration from Sweden first six months 2021')
plt.tight_layout()
plt.show()
